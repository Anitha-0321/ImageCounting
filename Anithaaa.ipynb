# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\mudde\anaconda3\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\mudde\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mudde\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cvlib
# Out:
# Collecting cvlibNote: you may need to restart the kernel to use updated packages.
#   Downloading cvlib-0.2.7.tar.gz (13.1 MB)
# Requirement already satisfied: numpy in c:\users\mudde\anaconda3\lib\site-packages (from cvlib) (1.26.4)
# Collecting progressbar
#   Downloading progressbar-2.5.tar.gz (10 kB)
# Requirement already satisfied: requests in c:\users\mudde\anaconda3\lib\site-packages (from cvlib) (2.27.1)
# Requirement already satisfied: pillow in c:\users\mudde\anaconda3\lib\site-packages (from cvlib) (9.0.1)
# Requirement already satisfied: imageio in c:\users\mudde\anaconda3\lib\site-packages (from cvlib) (2.9.0)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mudde\anaconda3\lib\site-packages (from requests->cvlib) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mudde\anaconda3\lib\site-packages (from requests->cvlib) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mudde\anaconda3\lib\site-packages (from requests->cvlib) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mudde\anaconda3\lib\site-packages (from requests->cvlib) (2.0.4)
# Building wheels for collected packages: cvlib, imutils, progressbar
#   Building wheel for cvlib (setup.py): started
#   Building wheel for cvlib (setup.py): finished with status 'done'
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046385 sha256=2488ff034c0df0892fcb75cd877ce7753ab3900831824a5d7fb305dc07d957b7
#   Stored in directory: c:\users\mudde\appdata\local\pip\cache\wheels\96\ad\4c\d80d4bf4143c154ab297e2384915c89aff43d77d1787b9a702
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25872 sha256=b0b4fcbf104a49385376f4a6a1f38497ee14a5652472d7787d1a3f052411400c
#   Stored in directory: c:\users\mudde\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
#   Building wheel for progressbar (setup.py): started
#   Building wheel for progressbar (setup.py): finished with status 'done'
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=9cfa80dc04f01c1c1a6502d5c95de43244215cca2d08c1bfe5a8759734721b9f
#   Stored in directory: c:\users\mudde\appdata\local\pip\cache\wheels\d7\d9\89\a3f31c76ff6d51dc3b1575628f59afe59e4ceae3f2748cd7ad
# Successfully built cvlib imutils progressbar
# Installing collected packages: progressbar, imutils, cvlib
# Successfully installed cvlib-0.2.7 imutils-0.5.4 progressbar-2.5

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

image = cv2.imread("cars.webp")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are " +str(label.count('car')))
# Out:
# C:\Users\mudde\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Number of cars in this image are 8
